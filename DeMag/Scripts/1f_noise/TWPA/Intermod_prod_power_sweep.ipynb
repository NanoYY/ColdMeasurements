# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib qt

import numpy as np
from numpy import *
import h5py

import os
import scipy.io as sio
# Out:
# C:\Users\Demag\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
initial_folder = r'C:\Users\Demag\PycharmProjects\ColdMeasurements\DeMag\DATA\TWPA_noise'

folders = os.listdir(initial_folder)
for i in range(len(folders)):
    if ".fig" in folders[i]: pass
    else: 
        print(r"[%d]" %(i), '----------->', folders[i])
# Out:
# [0] -----------> -22db_DC_sweep.png
# [1] -----------> -28db_DC_sweep.png
# [2] -----------> 1f noise
# [3] -----------> 1st_tone
# [4] -----------> 2023-09-18
# [5] -----------> 2023-09-19
# [6] -----------> 2023-09-20
# [7] -----------> 2023-09-26
# [8] -----------> 2nd_tone
# [9] -----------> InteProd_DC_sweep_fp_m10_fm_24
# [10] -----------> Intermodulation products
# [11] -----------> Intermodulation products_no_filter
# [12] -----------> IntProd graphs
# [13] -----------> IntProd_DC_sweep_fp_m10_fm_m22
# [14] -----------> IntProd_DC_sweep_fp_m10_fm_m22_no_2nd_mode
# [15] -----------> IntProd_DC_sweep_fp_m10_fm_m28
# [16] -----------> IntProd_DC_sweep_fp_m12_fm_m22
# [17] -----------> IntProd_DC_sweep_fp_m12_fm_m24
# [18] -----------> IntProd_DC_sweep_fp_m12_fm_m28
# [19] -----------> IntProd_DC_sweep_fp_m4_fm_m28
# [20] -----------> IntProd_DC_sweep_fp_m5_fm_m22
# [21] -----------> IntProd_DC_sweep_fp_m5_fm_m24
# [22] -----------> IntProd_DC_sweep_fp_m5_fm_m28
# [23] -----------> IntProd_DC_sweep_fp_m6_fm_m22
# [24] -----------> IntProd_DC_sweep_fp_m6_fm_m24
# [25] -----------> IntProd_DC_sweep_fp_m6_fm_m28
# [26] -----------> Katia
# [27] -----------> Line_calibration
# [28] -----------> Long_scan
# [29] -----------> Markus1OverFNoise
# [30] -----------> MarkusGainSweep
# [31] -----------> MarkusIntermodulationProducts
# [32] -----------> Small_reg_scan
# [33] -----------> Small_scan

# %%
folder = folders[22]
files = os.listdir(initial_folder+"\\"+folder)
for i in range(len(files)):
    if ".fig" in files[i]: pass
    else: 
        print(r"[%d]" %(i), '----------->', files[i])
# Out:
# [0] -----------> InterProd_powers -5--28.0--28.0__Dc_1.517-00-33.mat
# [1] -----------> InterProd_powers -5--28.0--28.0__Dc_1.522471910112359617-00-33.mat
# [2] -----------> InterProd_powers -5--28.0--28.0__Dc_1.544943820224719217-00-33.mat
# [3] -----------> InterProd_powers -5--28.0--28.0__Dc_1.567415730337078617-00-33.mat
# [4] -----------> InterProd_powers -5--28.0--28.0__Dc_1.589887640449438217-00-33.mat
# [5] -----------> InterProd_powers -5--28.0--28.0__Dc_1.612359550561797817-00-33.mat
# [6] -----------> InterProd_powers -5--28.0--28.0__Dc_1.634831460674157217-00-33.mat
# [7] -----------> InterProd_powers -5--28.0--28.0__Dc_1.657303370786516817-00-33.mat
# [8] -----------> InterProd_powers -5--28.0--28.0__Dc_1.679775280898876417-00-33.mat
# [9] -----------> InterProd_powers -5--28.0--28.0__Dc_1.70224719101123617-00-33.mat
# [77] -----------> InterProd_powers -5--28.0--28.0__Dc_3.230337078651685617-00-33.mat
# [78] -----------> InterProd_powers -5--28.0--28.0__Dc_3.25280898876404517-00-33.mat
# [79] -----------> InterProd_powers -5--28.0--28.0__Dc_3.275280898876404417-00-33.mat
# [80] -----------> InterProd_powers -5--28.0--28.0__Dc_3.29775280898876417-00-33.mat
# [81] -----------> InterProd_powers -5--28.0--28.0__Dc_3.320224719101123617-00-33.mat
# [82] -----------> InterProd_powers -5--28.0--28.0__Dc_3.34269662921348317-00-33.mat
# [83] -----------> InterProd_powers -5--28.0--28.0__Dc_3.365168539325842417-00-33.mat
# [84] -----------> InterProd_powers -5--28.0--28.0__Dc_3.387640449438202417-00-33.mat
# [85] -----------> InterProd_powers -5--28.0--28.0__Dc_3.410112359550561617-00-33.mat
# [86] -----------> InterProd_powers -5--28.0--28.0__Dc_3.43258426966292117-00-33.mat
# [87] -----------> InterProd_powers -5--28.0--28.0__Dc_3.45505617977528117-00-33.mat
# [88] -----------> InterProd_powers -5--28.0--28.0__Dc_3.477528089887640417-00-33.mat
# [89] -----------> InterProd_powers -5--28.0--28.0__Dc_3.517-00-33.mat

# %%
font = {'size'   : 15}
matplotlib.rc('font', **font)

fig, ax = plt.subplots(figsize=(15,10))
ax.set_xlabel('Frequency, GHz')
ax.set_ylabel('Magnitude, dB')

file = files[45]
mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
flux_power = mat['flux_power'][0,0]
flux_freq = mat['flux_freq'][0,0]/1e9
mode1 = mat['mode1'][0,0]/1e9
mode1_power = mat['mode1_power'][0,0]
mode2 = mat['mode2'][0,0]/1e9
mode2_power = mat['mode2_power'][0,0]
band_Hz = mat['band_Hz'][0,0]
nop = mat['nop'][0,0]

freq_sweep = mat['freq_sweep'][0]
data = mat['data'][0]

ax.vlines(flux_freq/2, 0, -105, 'r','--', linewidth=1.0,  label = '$\omega_{p}/2$')

ax.vlines(mode1, 0, -105, '#c6f808',linewidth=4.0, alpha = 0.4)
ax.vlines(mode2, 0, -105, '#a7ffb5',linewidth=4.0, alpha = 0.5)

ax.vlines(flux_freq-mode1, 0, -105, '#c6f808',linewidth=4.0, alpha = 0.4)
ax.vlines(flux_freq-mode2, 0, -105, '#a7ffb5',linewidth=4.0, alpha = 0.5)

ax.text(flux_freq/2-0.00045, -8, '$\omega_{p}/2$', size=15, rotation = 90)
ax.text(mode1-0.0005, -8, '$\omega_{1}$', size=15, rotation = 90)
ax.text(mode2-0.0005, -8, '$\omega_{2}$', size=15, rotation = 90)

ax.text(flux_freq-mode1-0.00045, -8, '$\omega_{p}-\omega_{1}$', size=15, rotation = 90)
ax.text(flux_freq-mode2-0.00045, -8, '$\omega_{p}-\omega_{2}$', size=15, rotation = 90)


ax.text(3*mode2-2*mode1-0.00045, -8, '$3\omega_{2}-2\omega_{1}$', size=15, rotation = 90)
ax.text(3*mode1-2*mode2-0.00045, -8, '$3\omega_{1}-2\omega_{2}$', size=15, rotation = 90)

ax.text(2*mode2-mode1-0.00045, -8, '$2\omega_{2}-\omega_{1}$', size=15, rotation = 90)
ax.text(2*mode1-mode2-0.00045, -8, '$2\omega_{1}-\omega_{2}$', size=15, rotation = 90)

ax.text(5*mode2-4*mode1-0.00045, -8, '$5\omega_{2}-4\omega_{1}$', size=15, rotation = 90)
ax.text(5*mode1-4*mode2-0.00045, -8, '$5\omega_{1}-4\omega_{2}$', size=15, rotation = 90)

ax.text(4*mode2-3*mode1-0.00045, -8, '$4\omega_{2}-3\omega_{1}$', size=15, rotation = 90)
ax.text(4*mode1-3*mode2-0.00045, 6, '$4\omega_{1}-3\omega_{2}$', size=15, rotation = 90)

ax.text(flux_freq - 2*mode2+1*mode1-0.00045, -8, '$\omega_{p} - 2\omega_{2}+\omega_{1}$', size=15, rotation = 90)
ax.text(flux_freq - 2*mode1+1*mode2-0.00045, -8, '$\omega_{p} - 2\omega_{1}+\omega_{2}$', size=15, rotation = 90)

ax.text(flux_freq - 3*mode2+2*mode1-0.00045, -8, '$\omega_{p} - 3\omega_{2}+2\omega_{1}$', size=15, rotation = 90)
ax.text(flux_freq - 3*mode1+2*mode2-0.00045, 6, '$\omega_{p} - 3\omega_{1}+2\omega_{2}$', size=15, rotation = 90)


ax.vlines(2*mode1-mode2, 0, -105, '#0a481e', '--', linewidth=1.0, alpha = 0.2)
ax.vlines(2*mode2-mode1, 0, -105, '#0a481e', '--', linewidth=1.0, alpha = 0.2)

for i in range(2,len(modes_fr_3ph)-2):
    ax.vlines(modes_fr_3ph[i], 0, -105, '#0a481e', '--', linewidth=1.0, alpha = 0.2)

for i in range(7, len(modes_fr_5ph)):
    ax.vlines(modes_fr_5ph[i], 0, -105, '#0a481e', '--', linewidth=1.0, alpha = 0.2)

for i in range(6,len(modes_fr_7ph)):
    ax.vlines(modes_fr_7ph[i], 0, -105, '#0a481e', '--', linewidth=1.0, alpha = 0.2)
    
    
# ax.text(5.606, -22, r'$\omega = i\cdot\frac{\omega_{p}}{2}+j\cdot\omega_{1}+k\cdot\omega_{2}$', size=15)




ax.plot(freq_sweep/1e9, data, label='Raw data')


ax.set_ylim(-100, -10)
ax.set_xlim(5.604,5.647)
# ax.legend(loc = 1, prop={'size': 11})
# Out:
# (5.604, 5.647)

# %%
colors*255
# Out:
# array([[  8.        ,  48.        , 107.        , 255.        ],
#        [  8.        ,  69.74117647, 139.28235294, 255.        ],
#        [ 15.94117647,  91.16470588, 163.94117647, 255.        ],
#        [ 33.25882353, 113.25882353, 181.13333333, 255.        ],
#        [ 55.        , 135.        , 192.33333333, 255.        ],
#        [ 79.34509804, 155.11372549, 203.20784314, 255.        ],
#        [107.8       , 174.43921569, 214.17254902, 255.        ],
#        [141.4       , 192.88627451, 221.41960784, 255.        ],
#        [171.33333333, 207.66666667, 229.66666667, 255.        ],
#        [198.56470588, 219.37647059, 239.18823529, 255.        ],
#        [214.37647059, 229.91764706, 244.45882353, 255.        ],
#        [230.52941176, 240.45882353, 249.72941176, 255.        ],
#        [247.        , 251.        , 255.        , 255.        ]])

# %%
# %matplotlib qt

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

font = {'size'   : 12}
matplotlib.rc('font', **font)

fig, ax = plt.subplots(figsize=(12,7))
ax.set_xlabel('DC bias, V')
ax.set_ylabel('Magnitude, dB')


treshhold = 3
cmap = plt.get_cmap('Purples_r')
x = np.linspace(0, 1, int(len(modes_fr_1ph_sort)+2))
colors = cmap(x)
control_color = -1
marker_list = [ ">", "D", "o", "v", "<", "p","2"]
ml=-1
for im, m in enumerate(modes_fr_1ph_sort):
    control_color += 1
    mag = np.array([])
    power = np.array([])
    for i in range(len(files)-1):
        file = files[i+1]
        mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
        mode1_power = mat['mode1_power'][0,0]
        volt = mat['volt'][0,0]
        freq_sweep = mat['freq_sweep'][0]
        data = mat['data'][0]
        
        mode_index = find_nearest(freq_sweep/1e9, m)
        mag_max = max(data[mode_index-10:mode_index+10])
        mag = np.append(mag, data[mode_index])
        power = np.append(power, volt)
    if max(mag)-min(mag)>treshhold:
        ml +=1
        if np.round(m,3)==mat['flux_freq'][0,0]/1e9/2:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], color = colors[control_color], 
                    linestyle='-.', markersize=2, linewidth=1.5, label = '$\omega_{p}/2$', zorder=10)
            
        if np.round(m,3)==mat['mode1'][0,0]/1e9:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], color = colors[control_color], 
                    linestyle='dotted', markersize=2, linewidth=1.5, label = '$\omega_{1}$', zorder=10)
            
        if np.round(m,3)==mat['mode1'][0,0]/1e9:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], color = colors[control_color], 
                    linestyle='--', markersize=2, linewidth=1.5, label = '$\omega_{2}$', zorder=10)


colors = cmap(x)
control_color = -1
marker_list = [ ">", "D", "o", "v", "<", "p","2"]
ml=-1
for im, m in enumerate(modes_fr_3ph_sort):
    control_color += 1
    mag = np.array([])
    power = np.array([])
    for i in range(len(files)-1):
        file = files[i+1]
        mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
        mode1_power = mat['mode1_power'][0,0]
        volt = mat['volt'][0,0]
        freq_sweep = mat['freq_sweep'][0]
        data = mat['data'][0]
        
        mode_index = find_nearest(freq_sweep/1e9, m)
        mag_max = max(data[mode_index-10:mode_index+10])
        mag = np.append(mag, data[mode_index])
        power = np.append(power, volt)
    if max(mag)-min(mag)>treshhold:
        ml +=1
        if im == 3:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                color = '#acc2d9', linewidth=1, label = '3 photon products', zorder=3)
        else: ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                color = '#acc2d9', linewidth=1, zorder=3)


cmap = plt.get_cmap('YlOrBr_r')
x = np.linspace(0, 1, int(len(modes_fr_5ph_sort)+5))
colors = cmap(x)
control_color = -1
marker_list = [ ">", "D", "o", "v", "<", "p","2"]
ml=-1
for im, m in enumerate(modes_fr_5ph_sort):
    control_color += 1
    mag = np.array([])
    power = np.array([])
    for i in range(len(files)-1):
        file = files[i+1]
        mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
        mode1_power = mat['mode1_power'][0,0]
        volt = mat['volt'][0,0]
        freq_sweep = mat['freq_sweep'][0]
        data = mat['data'][0]
        
        mode_index = find_nearest(freq_sweep/1e9, m)
        mag_max = max(data[mode_index-10:mode_index+10])
        mag = np.append(mag, data[mode_index])
        power = np.append(power, volt)
    if max(mag)-min(mag)>treshhold:
        ml +=1
        if im==3:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                    color = '#7B081A', linewidth=1, label = '5 photon products', zorder=3)
        else: ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                    color = '#7B081A', linewidth=1, zorder=3)

        
cmap = plt.get_cmap('Blues_r')
x = np.linspace(0, 1, int(len(modes_fr_7ph_sort)+5))
colors = cmap(x)
control_color = -1
marker_list = [ ">", "D", "o", "v", "<", "p","2"]
ml=-1
for im, m in enumerate(modes_fr_7ph_sort):
    control_color += 1
    mag = np.array([])
    power = np.array([])
    for i in range(len(files)-1):
        file = files[i+1]
        mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
        mode1_power = mat['mode1_power'][0,0]
        volt = mat['volt'][0,0]
        freq_sweep = mat['freq_sweep'][0]
        data = mat['data'][0]
        flux_power = mat['flux_power'][0,0]
        
        mode_index = find_nearest(freq_sweep/1e9, m)
        mag_max = max(data[mode_index-10:mode_index+10])
        mag = np.append(mag, data[mode_index])
        power = np.append(power, volt)
    if max(mag)-min(mag)>treshhold:
        ml +=1
        if im ==3: 
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                color = '#86b87b', linewidth=1, label = '7 photon products', zorder=3)
        else: 
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                color = '#86b87b', linewidth=1, zorder=3)
    
ax.vlines(2.5, 0, -105, '#610023', linewidth=1.0, label = 'Large intermodulation\n products regime', zorder=99)
ax.vlines(2.25, 0, -105, '#be013c',linewidth=1.0,  label = 'Small intermodulation\n products regime', zorder=99)
ax.set_ylim(-105, 0)
        
ax.legend(loc = 1, prop={'size': 11}).set_zorder(101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      16 treshhold = 3
#      17 cmap = plt.get_cmap('Purples_r')
# ---> 18 x = np.linspace(0, 1, int(len(modes_fr_1ph_sort)+2))
#      19 colors = cmap(x)
#      20 control_color = -1
#
# NameError: name 'modes_fr_1ph_sort' is not defined

# %%
file = files[10]
mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
flux_power = mat['flux_power'][0,0]
flux_freq = mat['flux_freq'][0,0]
mode1 = mat['mode1'][0,0]
mode1_power = mat['mode1_power'][0,0]
mode2 = mat['mode2'][0,0]
mode2_power = mat['mode2_power'][0,0]
band_Hz = mat['band_Hz'][0,0]
nop = mat['nop'][0,0]

freq_sweep = mat['freq_sweep'][0]
data = mat['data'][0]
print('fpow: {}, mpow: {}'.format(flux_power, mode1_power))
# Out:
# fpow: -5, mpow: -28.0

# %%
fig, ax = plt.subplots(figsize=(20,15))
ax.set_ylim(-110, 0)

for i in range(len(files)-1):
    file = files[i+1]
    mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
    flux_power = mat['flux_power'][0,0]
    flux_freq = mat['flux_freq'][0,0]
    mode1 = mat['mode1'][0,0]
    mode1_power = mat['mode1_power'][0,0]
    mode2 = mat['mode2'][0,0]
    mode2_power = mat['mode2_power'][0,0]
    band_Hz = mat['band_Hz'][0,0]
    nop = mat['nop'][0,0]

    freq_sweep = mat['freq_sweep'][0]
    data = mat['data'][0]
    
    ax.set_title('Powers = {}-{}-{}, flux_freq = {}'.format(flux_power, mode1_power, mode2_power, round(flux_freq/1e9, 3)))
    ax.plot(freq_sweep/1e9, data, label = r'mode power: {}'.format(mode1_power))
    
    ax.axvline(flux_freq/1e9/2, ymin=-100, ymax=1, linestyle=':', linewidth=2, color='r',
                               alpha = 1)
ax.legend()

# %%
mat['volt'][0,0]
# Out:
# 3.5

# %%
# find mode array

mp = flux_freq/2/1e9
m1 = mode1/1e9
m2 = mode2/1e9

def get_mode(i, j, k, mp, m1, m2):
    return i*mp+j*m1+k*m2

range_i = np.array([0, 1, -1, 2, -2, 3, -3, 4, -4])

modes_fr_all = np.array([])
modes_fr_1ph = np.array([])
modes_fr_2ph = np.array([])
modes_fr_3ph = np.array([])
modes_fr_4ph = np.array([])
modes_fr_5ph = np.array([])
modes_fr_6ph = np.array([])
modes_fr_7ph = np.array([])
for i in range_i:
    for j in range_i:
        for k in range_i:
            mode = np.round(get_mode(i, j, k, mp, m1, m2),3)
            if mode<max(freq_sweep/1e9) and mode>min(freq_sweep/1e9):
                modes_fr_all = np.append(modes_fr_all, mode)
                
                if int(abs(i)+abs(j)+abs(k))==1: modes_fr_1ph = np.append(modes_fr_1ph, mode)
                    
                if int(abs(i)+abs(j)+abs(k))==2: 
                    modes_fr_2ph = np.append(modes_fr_2ph, mode)
                        
                if int(abs(i)+abs(j)+abs(k))==3: 
                    modes_fr_3ph = np.append(modes_fr_3ph, mode)
                            
                if int(abs(i)+abs(j)+abs(k))==4: 
                    modes_fr_4ph = np.append(modes_fr_4ph, mode)
                                
                if int(abs(i)+abs(j)+abs(k))==5: 
                    modes_fr_5ph = np.append(modes_fr_5ph, mode)
                                    
                if int(abs(i)+abs(j)+abs(k))==6: 
                    modes_fr_6ph = np.append(modes_fr_6ph, mode)
                                        
                if int(abs(i)+abs(j)+abs(k))==7: 
                    modes_fr_7ph = np.append(modes_fr_7ph, mode)
                    
modes_fr_1ph_sort = np.unique(np.sort(np.round(modes_fr_1ph,3)))
modes_fr_2ph_sort = np.unique(np.sort(np.round(modes_fr_2ph,3)))
modes_fr_3ph_sort = np.unique(np.sort(np.round(modes_fr_3ph,3)))
modes_fr_4ph_sort = np.unique(np.sort(np.round(modes_fr_4ph,3)))
modes_fr_5ph_sort = np.unique(np.sort(np.round(modes_fr_5ph,3)))
modes_fr_6ph_sort = np.unique(np.sort(np.round(modes_fr_6ph,3)))
modes_fr_7ph_sort = np.unique(np.sort(np.round(modes_fr_7ph,3)))

modes_fr_all_sort = np.unique(np.sort(np.round(modes_fr_all,3)))

ind_3 = np.array([], dtype=int)
for i in range(len(modes_fr_3ph_sort)):
    if np.any(modes_fr_1ph_sort == modes_fr_3ph_sort[i]):
        ind_3 = np.append(ind_3, i)
    
modes_fr_3ph_sort = np.delete(modes_fr_3ph_sort, ind_3)

ind_5 = np.array([], dtype=int)
for i in range(len(modes_fr_5ph_sort)):
    if np.any(modes_fr_1ph_sort == modes_fr_5ph_sort[i]) or np.any(modes_fr_3ph_sort == modes_fr_5ph_sort[i]):
        ind_5 = np.append(ind_5, i)
    
modes_fr_5ph_sort = np.delete(modes_fr_5ph_sort, ind_5)

ind_7 = np.array([], dtype=int)
for i in range(len(modes_fr_7ph_sort)):
    if np.any(modes_fr_1ph_sort == modes_fr_7ph_sort[i]) or np.any(modes_fr_3ph_sort == modes_fr_7ph_sort[i]) or np.any(modes_fr_5ph_sort == modes_fr_7ph_sort[i]):
        ind_7 = np.append(ind_7, i)
    
modes_fr_7ph_sort = np.delete(modes_fr_7ph_sort, ind_7)

# %%
print(modes_fr_sort[0])
# Out:
# 5.613000000000003

# %%
file_name=r'C:\Users\Demag\PycharmProjects\ColdMeasurements\DeMag\DATA\TWPA_noise\Daffing scan\Daffing_12-12-08.h5'
h5f = h5py.File(file_name, 'r')
print(h5f.keys())
data = np.array(h5f['0'])
print(data)
h5f.close()
# Out:
# <KeysViewHDF5 ['0']>
# [ 1.04242426  0.93890214  0.90558421 -0.47860556  0.31054404 -1.02053224
#   0.70737366  0.0248586   0.64795458 -0.19895264]

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

font = {'size'   : 10}
matplotlib.rc('font', **font)

fig, ax = plt.subplots(figsize=(10,5))
ax.set_xlabel('DC bias, V')
ax.set_ylabel('Magnitude, dB')


treshhold = 3
cmap = plt.get_cmap('Purples_r')
x = np.linspace(0, 1, int(len(modes_fr_1ph_sort)+2))
colors = cmap(x)
control_color = -1
marker_list = [ ">", "D", "o", "v", "<", "p","2"]
ml=-1
for im, m in enumerate(modes_fr_1ph_sort):
    control_color += 1
    mag = np.array([])
    power = np.array([])
    for i in range(len(files)-1):
        file = files[i+1]
        mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
        mode1_power = mat['mode1_power'][0,0]
        volt = mat['volt'][0,0]
        freq_sweep = mat['freq_sweep'][0]
        data = mat['data'][0]
        
        mode_index = find_nearest(freq_sweep/1e9, m)
        mag_max = max(data[mode_index-10:mode_index+10])
        mag = np.append(mag, data[mode_index])
        power = np.append(power, volt)
    if max(mag)-min(mag)>treshhold:
        ml +=1
        if np.round(m,3)==mat['flux_freq'][0,0]/1e9/2:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], color = colors[control_color], 
                    linestyle='-.', markersize=3, label = '$\omega_{p}/2$', zorder=10)
            
        if np.round(m,3)==mat['mode1'][0,0]/1e9:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], color = colors[control_color], 
                    linestyle='dotted', markersize=3, label = '$\omega_{1}$', zorder=10)
            
        if np.round(m,3)==mat['mode1'][0,0]/1e9:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], color = colors[control_color], 
                    linestyle='--', markersize=3, label = '$\omega_{2}$', zorder=10)


cmap = plt.get_cmap('summer')
x = np.linspace(0, 1, int(len(modes_fr_3ph_sort)+2))
colors = cmap(x)
control_color = -1
marker_list = [ ">", "D", "o", "v", "<", "p","2"]
ml=-1
for im, m in enumerate(modes_fr_3ph_sort):
    control_color += 1
    mag = np.array([])
    power = np.array([])
    for i in range(len(files)-1):
        file = files[i+1]
        mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
        mode1_power = mat['mode1_power'][0,0]
        volt = mat['volt'][0,0]
        freq_sweep = mat['freq_sweep'][0]
        data = mat['data'][0]
        
        mode_index = find_nearest(freq_sweep/1e9, m)
        mag_max = max(data[mode_index-10:mode_index+10])
        mag = np.append(mag, data[mode_index])
        power = np.append(power, volt)
    if max(mag)-min(mag)>treshhold:
        ml +=1
        if im == 3:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                color = colors[control_color], linewidth=1, label = '3 photon product', zorder=3)
        else: ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                color = colors[control_color], linewidth=1, zorder=3)


cmap = plt.get_cmap('YlOrBr_r')
x = np.linspace(0, 1, int(len(modes_fr_5ph_sort)+5))
colors = cmap(x)
control_color = -1
marker_list = [ ">", "D", "o", "v", "<", "p","2"]
ml=-1
for im, m in enumerate(modes_fr_5ph_sort):
    control_color += 1
    mag = np.array([])
    power = np.array([])
    for i in range(len(files)-1):
        file = files[i+1]
        mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
        mode1_power = mat['mode1_power'][0,0]
        volt = mat['volt'][0,0]
        freq_sweep = mat['freq_sweep'][0]
        data = mat['data'][0]
        
        mode_index = find_nearest(freq_sweep/1e9, m)
        mag_max = max(data[mode_index-10:mode_index+10])
        mag = np.append(mag, data[mode_index])
        power = np.append(power, volt)
    if max(mag)-min(mag)>treshhold:
        ml +=1
        if im==3:
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                    color = colors[control_color], linewidth=1, label = '5 photon product', zorder=3)
        else: ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                    color = colors[control_color], linewidth=1, zorder=3)

        
cmap = plt.get_cmap('Blues_r')
x = np.linspace(0, 1, int(len(modes_fr_7ph_sort)+5))
colors = cmap(x)
control_color = -1
marker_list = [ ">", "D", "o", "v", "<", "p","2"]
ml=-1
for im, m in enumerate(modes_fr_7ph_sort):
    control_color += 1
    mag = np.array([])
    power = np.array([])
    for i in range(len(files)-1):
        file = files[i+1]
        mat = sio.loadmat(initial_folder+"\\"+folder+"\\"+file)
        mode1_power = mat['mode1_power'][0,0]
        volt = mat['volt'][0,0]
        freq_sweep = mat['freq_sweep'][0]
        data = mat['data'][0]
        flux_power = mat['flux_power'][0,0]
        
        mode_index = find_nearest(freq_sweep/1e9, m)
        mag_max = max(data[mode_index-10:mode_index+10])
        mag = np.append(mag, data[mode_index])
        power = np.append(power, volt)
    if max(mag)-min(mag)>treshhold:
        ml +=1
        if im ==3: 
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                color = colors[control_color], linewidth=1, label = '7 photon product', zorder=3)
        else: 
            ax.plot(power, mag, marker = marker_list[mod(ml,5)], markersize=2,
                color = colors[control_color], linewidth=1, zorder=3)
    
ax.vlines(2.5, 0, -105, '#00fbb0', linewidth=1.0, label = 'Large intermodulation\n products regime')
ax.vlines(2.25, 0, -105, '#8ee53f',linewidth=1.0,  label = 'Small intermodulation\n products regime')
ax.set_ylim(-105, 0)
        
ax.legend(loc = 1, prop={'size': 11}).set_zorder(101)
