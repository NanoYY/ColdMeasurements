# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as sio
import os
import datetime
from nanodrivers.visa_drivers.signal_analyser import Anri
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"


from presto.hardware import AdcFSample, AdcMode, DacFSample, DacMode
from presto import lockin, utils
# from presto.utils import ProgressBar

# %%
ADDRESS = "169.254.3.14"  # Presto's IP address

CONVERTER_CONFIGURATION = {
    "adc_mode": AdcMode.Mixed,  # Use digital downconversion.
    "adc_fsample": AdcFSample.G2,  # 4 GS/s sampling rate.
    "dac_mode": DacMode.Mixed42,  # Use digital upconversion.
    "dac_fsample": DacFSample.G10,  # 10 GS/s sampling rate.
}

# %%
anri = Anri()
anri.idn()
# Out:
# Connection exist: ANRITSU,MS2830A,6200847105,4.09.01

# %%
# ******************************
# *** define some parameters ***
# ******************************

INPUT_PORT = 5 # Somewhat confusingly, input is the listening port,
SG_PORT = 1
file_number = 1

DEL_OMEGA = 200
NR_STEPS = 80
DETUNING = 0.30e9
DF = 5 * 1e0 # Sampling Rate.
CENT_FREQ = 3.798 * 1e9
NCO_PHASE_OUT = 0*np.pi/180 # NCO output phase.
NCO_PHASE_IN = 0*np.pi/180 # NCO input phase.

OMEGA1 = -DEL_OMEGA/2
OMEGA2 = DEL_OMEGA/2

SG_FREQ_OUT = DETUNING + np.array([OMEGA1, OMEGA2])
FREQ_IN_MULT = np.mean(SG_FREQ_OUT)+np.linspace(OMEGA1*(NR_STEPS/4),OMEGA2*(NR_STEPS/4),NR_STEPS+1) # Lets gather data on multiple freequencies at the same time.
FREQ_IN = FREQ_IN_MULT
NR_FREQS_SG = len(SG_FREQ_OUT) # Number of output detunings, needed for method.
NR_FREQS_IN = len(FREQ_IN) # Same for input.
NR_MODES = NR_FREQS_IN/2
PHASE_SG = np.array([0 * np.pi/16, 0 * np.pi/16]) # Output group phase.
PHASE_SG_Q = PHASE_SG - np.pi/2
PHASE_IN = [0 * np.pi/16] # Input group phase.

DITHER = True 

NR_MEAS = 1 * 1e2 # Number of measured points both for raw and summed.
DAC_CURRENT = 40_500 # NCO current in micro amps, 40_500 is maximum and 2_250 is minimum.

#Parameters for frequency sweep
FREQ_SWEEP_SPAN = 8e6 #Span of the sweep
CENT_FREQ_ARR = np.flip(np.linspace(CENT_FREQ-FREQ_SWEEP_SPAN/2, CENT_FREQ+FREQ_SWEEP_SPAN/2, 200)) #Array for the central freqs of the sweep
NR_CENT_FREQ = len(CENT_FREQ_ARR)

#Parameters for power sweep
Amplitude, power_array = amplitudeArray(-15,-15,-5,-14)
NR_AMPLITUDE = len(Amplitude)
NR_AVE = 1

Mag = np.zeros((int(NR_AMPLITUDE),int(NR_CENT_FREQ),int(NR_STEPS+1)))
Pha = np.zeros((int(NR_AMPLITUDE),int(NR_CENT_FREQ),int(NR_STEPS+1)))

ff = NR_CENT_FREQ - 1
for f in CENT_FREQ_ARR:
    #print(ff)
    NCO_FREQ = f - DETUNING # Numerically Controlled Oscillator (NCO) frequency. Can be defined separately for input and output. Riccardo says bad idea.

    with lockin.Lockin(ext_ref_clk=False, address=ADDRESS, **CONVERTER_CONFIGURATION) as lck:

        lck.hardware.set_adc_attenuation(INPUT_PORT, 0.0) # Attenuation at input, why would you though?
        lck.hardware.set_dac_current(SG_PORT, DAC_CURRENT) # Set NCO current for output.
        lck.hardware.configure_mixer(NCO_FREQ, out_ports=[SG_PORT], out_phase = NCO_PHASE_OUT, sync=False) # Configure input and output NCOs.
        lck.hardware.configure_mixer(NCO_FREQ+CENT_FREQ, in_ports=INPUT_PORT,  in_phase = NCO_PHASE_IN, sync=True) # Configure input and
        
        lck.set_phase_reset(False) # Reset phase of ig and og at the start of every lockin cycle.
        lck.set_dither(DITHER, SG_PORT) # Adds dither to the output ports when set True.

        freq_sg, df = lck.tune(SG_FREQ_OUT,DF) # Tunes the sampling rate in such a way that each lockin cycle has n full wavelengths.

        sgg = lck.add_output_group(ports=SG_PORT, nr_freq=NR_FREQS_SG) # Create output group.
        sgg.set_frequencies(freq_sg) # Set output group detunings.
        sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
        freq_in, df = lck.tune(FREQ_IN,DF) # Previous was output group, this one is input.
        lck.set_df(df) # Set Sampling rate according to the tuning.


        ig = lck.add_input_group(INPUT_PORT, nr_freq=NR_FREQS_IN) # Create input group.
        ig.set_frequencies(freq_in) # Set input group detunings.
        ig.set_phases(phases=PHASE_IN) # Set input group phases. Rotating this equals basis transformation.

        #lck.hardware.set_inv_sinc([SG_PORT],2)

        lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
        lck.hardware.sleep(.2) # Sleep for 0.1 second as outputs are turned on and off during apply.

        jj = 0
        for AMP in Amplitude:
            # Set amplitude of the IF for experiment
            lck.hardware.blank_output(ports=[SG_PORT], state=False) # Reverse blanking outputs for excited state data.
            lck.hardware.sleep(0.1, False) # Sleep for a short duration to make sure device is in steady state.
            sgg.set_amplitudes([AMP,AMP]) # Set output group amplitudes.
            sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
            lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
            lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.

            # pixel_dict = lck.get_pixels(NR_MEAS, fir_coeffs=coeffs) # Measure a number of pixels: Measure IQ data.
            pixel_dict = lck.get_pixels(NR_MEAS) # Measure a number of pixels: Measure IQ data.
            freq, pixel_i, pixel_q = pixel_dict[INPUT_PORT] # Get IQ data.
            IQ1, IQ2 = utils.untwist_downconversion(pixel_i, pixel_q) # Separate lower and higher sidebands.

            for ii in range(NR_FREQS_IN):
                Mag[jj,ff,ii] = np.mean(np.absolute(IQ2[:,ii]))
                Pha[jj,ff,ii] = np.mean(np.angle(IQ2[:,ii], deg=False))
            jj = jj + 1

        ff = ff - 1

        sgg.set_amplitudes(np.zeros(NR_FREQS_SG))
        lck.set_trigger_out(0)
        lck.apply_settings()
        lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.
print('Measurement successful!')
# Out:
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7300.000000000005 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.959798994991 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.919597989941 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.879396984928 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.839195979914 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.798994974864 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.758793969851 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.718592964837 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.678391959787 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.638190954774 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.59798994976 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.55778894471 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.517587939697 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.477386934683 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.437185929633 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.39698492462 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.356783919606 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.316582914556 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.276381909543 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.236180904529 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.195979899479 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.1557788944665 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.115577889453 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.075376884439 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7299.0351758793895 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.994974874376 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.954773869362 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.9145728643125 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.874371859299 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.834170854285 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.7939698492355 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.753768844222 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.713567839208 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.6733668341585 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.633165829145 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.592964824131 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.5527638190815 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.512562814068 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.472361809054 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.4321608040045 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.391959798991 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.351758793977 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.3115577889275 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.271356783915 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.231155778901 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.190954773887 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.150753768838 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.110552763824 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.07035175881 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7298.030150753761 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.989949748747 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.949748743733 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.909547738684 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.86934673367 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.829145728656 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.788944723607 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.748743718593 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.708542713579 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.66834170853 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.628140703516 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.587939698502 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.547738693453 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.507537688439 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.467336683425 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.427135678376 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.386934673362 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.346733668348 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.306532663299 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.266331658286 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.226130653272 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.185929648258 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.145728643209 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.105527638195 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.065326633181 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7297.025125628132 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.984924623118 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.944723618104 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.904522613055 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.864321608041 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.824120603027 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.783919597978 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.743718592964 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.70351758795 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.663316582901 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.623115577887 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.582914572873 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.542713567824 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.50251256281 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.462311557796 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.422110552747 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.381909547734 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.34170854272 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.301507537706 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.261306532657 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.221105527643 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.180904522629 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.14070351758 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# C:\Users\Demag\anaconda3\lib\site-packages\presto\hardware.py:896: UserWarning: Frequency 7296.100502512566 MHz is outside recommended range for current DAC configuration Mixed42-G10 on tile 0. Recommended ranges for this configuration are:
#   - from 3000 to 4500 MHz
#   - from 5500 to 7000 MHz
#   - from 13000 to 14500 MHz
# Change frequency, or change DAC configuration. See also helper functon presto.utils.recommended_dac_config() for help.
#   self._configure_mixer_inner(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[401], line 92
#      89 lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.
#      91 # pixel_dict = lck.get_pixels(NR_MEAS, fir_coeffs=coeffs) # Measure a number of pixels: Measure IQ data.
# ---> 92 pixel_dict = lck.get_pixels(NR_MEAS) # Measure a number of pixels: Measure IQ data.
#      93 freq, pixel_i, pixel_q = pixel_dict[INPUT_PORT] # Get IQ data.
#      94 IQ1, IQ2 = utils.untwist_downconversion(pixel_i, pixel_q) # Separate lower and higher sidebands.
#
# File ~\anaconda3\lib\site-packages\presto\lockin.py:930, in Lockin.get_pixels(self, n, summed, fir_coeffs, nsum, quiet, auto_sync)
#     928         nr_bytes *= 2  # sum and sum squared
#     929         nr_bytes_get *= 2  # sum and sum squared
# --> 930     reply = self.hardware._receive_from(nr_bytes_get, sock)
#     932 self.hardware.assert_errors()
#     933 if not quiet:
#
# File ~\anaconda3\lib\site-packages\presto\hardware.py:520, in Hardware._receive_from(self, N, sock, status_callback)
#     518 expected = int(N)
#     519 buf = bytearray(expected)
# --> 520 self._receive_from_into(N, sock, buf, status_callback=status_callback)
#     521 return buf
#
# File ~\anaconda3\lib\site-packages\presto\hardware.py:532, in Hardware._receive_from_into(self, N, sock, buf, status_callback)
#     530 while received < expected:
#     531     remaining = expected - received
# --> 532     nb = sock.recv_into(view[received:expected], remaining)
#     533     if nb == 0:
#     534         raise RuntimeError(f"connection closed, got {received} bytes out of {expected}")
#
# KeyboardInterrupt:

# %%
now = datetime.datetime.now()  
folder = r'C:\Users\Demag\PycharmProjects\ColdMeasurements\DeMag\DATA\IMS_summer_pro\Presto data'
file = r'Presto_IMS_2Omega_[-15]_' + now.strftime(r'%Y%m%d%H%M%S') + '.mat'
file_name = folder +'\\' + file

# sio.savemat('DataIntermodulationDistortion_' + now.strftime("%Y_%m_%d_%H_%M_%S") + '.mat' , 
sio.savemat(file_name, 
            {'mag': Mag, 'pha': Pha, 'freq': FREQ_IN_MULT, 'sweep_cent_freq': CENT_FREQ, 'span': FREQ_SWEEP_SPAN, 'power': power_array})
print('File download successful!')
# Out:
# File download successful!

# %%
# ******************************
# *** define some parameters ***
# ******************************

INPUT_PORT = 5 # Somewhat confusingly, input is the listening port,
SG_PORT = 1
file_number = 1

DEL_OMEGA = 200
NR_STEPS = 80
DETUNING = 0.30e9
DF = 10 * 1e0 # Sampling Rate.
CENT_FREQ = 3.698 * 1e9
NCO_PHASE_OUT = 0*np.pi/180 # NCO output phase.
NCO_PHASE_IN = 0*np.pi/180 # NCO input phase.

OMEGA1 = -DEL_OMEGA/2
OMEGA2 = DEL_OMEGA/2

SG_FREQ_OUT = DETUNING + np.array([OMEGA1, OMEGA2])
FREQ_IN_MULT = np.mean(SG_FREQ_OUT)+np.linspace(OMEGA1*(NR_STEPS/2),OMEGA2*(NR_STEPS/2),NR_STEPS+1) # Lets gather data on multiple freequencies at the same time.
FREQ_IN = FREQ_IN_MULT
NR_FREQS_SG = len(SG_FREQ_OUT) # Number of output detunings, needed for method.
NR_FREQS_IN = len(FREQ_IN) # Same for input.
NR_MODES = NR_FREQS_IN/2
PHASE_SG = np.array([0 * np.pi/16, 0 * np.pi/16]) # Output group phase.
PHASE_SG_Q = PHASE_SG - np.pi/2
PHASE_IN = [0 * np.pi/16] # Input group phase.

DITHER = True 

NR_MEAS = 1 * 1e2 # Number of measured points both for raw and summed.
DAC_CURRENT = 40_500 # NCO current in micro amps, 40_500 is maximum and 2_250 is minimum.

#Parameters for frequency sweep
FREQ_SWEEP_SPAN = 20e6 #Span of the sweep
CENT_FREQ_ARR = np.flip(np.linspace(CENT_FREQ-FREQ_SWEEP_SPAN/2, CENT_FREQ+FREQ_SWEEP_SPAN/2, 100)) #Array for the central freqs of the sweep
NR_CENT_FREQ = len(CENT_FREQ_ARR)

#Parameters for power sweep
Amplitude, power_array = amplitudeArray(-15,-35,-10,-14)
NR_AMPLITUDE = len(Amplitude)
NR_AVE = 1

Mag = np.zeros((int(NR_AMPLITUDE),int(NR_CENT_FREQ),int(NR_STEPS+1)))
Pha = np.zeros((int(NR_AMPLITUDE),int(NR_CENT_FREQ),int(NR_STEPS+1)))

ff = NR_CENT_FREQ - 1
for f in CENT_FREQ_ARR:
    #print(ff)
    NCO_FREQ = f - DETUNING # Numerically Controlled Oscillator (NCO) frequency. Can be defined separately for input and output. Riccardo says bad idea.

    with lockin.Lockin(ext_ref_clk=False, address=ADDRESS, **CONVERTER_CONFIGURATION) as lck:

        lck.hardware.set_adc_attenuation(INPUT_PORT, 0.0) # Attenuation at input, why would you though?
        lck.hardware.set_dac_current(SG_PORT, DAC_CURRENT) # Set NCO current for output.
        lck.hardware.configure_mixer(NCO_FREQ, in_ports=INPUT_PORT, out_ports=[SG_PORT], 
                                     in_phase = NCO_PHASE_IN, out_phase = NCO_PHASE_OUT, sync=True) # Configure input and output NCOs.

        lck.set_phase_reset(False) # Reset phase of ig and og at the start of every lockin cycle.
        lck.set_dither(DITHER, SG_PORT) # Adds dither to the output ports when set True.

        freq_sg, df = lck.tune(SG_FREQ_OUT,DF) # Tunes the sampling rate in such a way that each lockin cycle has n full wavelengths.

        sgg = lck.add_output_group(ports=SG_PORT, nr_freq=NR_FREQS_SG) # Create output group.
        sgg.set_frequencies(freq_sg) # Set output group detunings.
        sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
        freq_in, df = lck.tune(FREQ_IN,DF) # Previous was output group, this one is input.
        lck.set_df(df) # Set Sampling rate according to the tuning.


        ig = lck.add_input_group(INPUT_PORT, nr_freq=NR_FREQS_IN) # Create input group.
        ig.set_frequencies(freq_in) # Set input group detunings.
        ig.set_phases(phases=PHASE_IN) # Set input group phases. Rotating this equals basis transformation.

        #lck.hardware.set_inv_sinc([SG_PORT],2)

        lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
        lck.hardware.sleep(.2) # Sleep for 0.1 second as outputs are turned on and off during apply.

        jj = 0
        for AMP in Amplitude:
            # Set amplitude of the IF for experiment
            lck.hardware.blank_output(ports=[SG_PORT], state=False) # Reverse blanking outputs for excited state data.
            lck.hardware.sleep(0.1, False) # Sleep for a short duration to make sure device is in steady state.
            sgg.set_amplitudes([AMP,AMP]) # Set output group amplitudes.
            sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
            lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
            lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.

            # pixel_dict = lck.get_pixels(NR_MEAS, fir_coeffs=coeffs) # Measure a number of pixels: Measure IQ data.
            pixel_dict = lck.get_pixels(NR_MEAS) # Measure a number of pixels: Measure IQ data.
            freq, pixel_i, pixel_q = pixel_dict[INPUT_PORT] # Get IQ data.
            IQ1, IQ2 = utils.untwist_downconversion(pixel_i, pixel_q) # Separate lower and higher sidebands.

            for ii in range(NR_FREQS_IN):
                Mag[jj,ff,ii] = np.mean(np.absolute(IQ2[:,ii]))
                Pha[jj,ff,ii] = np.mean(np.angle(IQ2[:,ii], deg=False))
            jj = jj + 1

        ff = ff - 1

        sgg.set_amplitudes(np.zeros(NR_FREQS_SG))
        lck.set_trigger_out(0)
        lck.apply_settings()
        lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.
print('Measurement successful!')
# Out:
# Measurement successful!

# %%
now = datetime.datetime.now()  
folder = r'C:\Users\Demag\PycharmProjects\ColdMeasurements\DeMag\DATA\IMS_summer_pro\Presto data'
file = r'Presto_IMS_offRes_2_[-15 to -35]_' + now.strftime(r'%Y%m%d%H%M%S') + '.mat'
file_name = folder +'\\' + file

# sio.savemat('DataIntermodulationDistortion_' + now.strftime("%Y_%m_%d_%H_%M_%S") + '.mat' , 
sio.savemat(file_name, 
            {'mag': Mag, 'pha': Pha, 'freq': FREQ_IN_MULT, 'sweep_cent_freq': CENT_FREQ, 'span': FREQ_SWEEP_SPAN, 'power': power_array})
print('File download successful!')
# Out:
# File download successful!

# %%
# ******************************
# *** define some parameters ***
# ******************************

INPUT_PORT = 5 # Somewhat confusingly, input is the listening port,
SG_PORT = 1
file_number = 1

DEL_OMEGA = 200
NR_STEPS = 80
DETUNING = 0.30e9
DF = 10 * 1e0 # Sampling Rate.
CENT_FREQ = 3.798 * 1e9
NCO_PHASE_OUT = 0*np.pi/180 # NCO output phase.
NCO_PHASE_IN = 0*np.pi/180 # NCO input phase.

OMEGA1 = -DEL_OMEGA/2
OMEGA2 = DEL_OMEGA/2

SG_FREQ_OUT = DETUNING + np.array([OMEGA1, OMEGA2])
FREQ_IN_MULT = np.mean(SG_FREQ_OUT)+np.linspace(OMEGA1*(NR_STEPS/2),OMEGA2*(NR_STEPS/2),NR_STEPS+1) # Lets gather data on multiple freequencies at the same time.
FREQ_IN = FREQ_IN_MULT
NR_FREQS_SG = len(SG_FREQ_OUT) # Number of output detunings, needed for method.
NR_FREQS_IN = len(FREQ_IN) # Same for input.
NR_MODES = NR_FREQS_IN/2
PHASE_SG = np.array([0 * np.pi/16, 0 * np.pi/16]) # Output group phase.
PHASE_SG_Q = PHASE_SG - np.pi/2
PHASE_IN = [0 * np.pi/16] # Input group phase.

DITHER = True 

NR_MEAS = 1 * 1e2 # Number of measured points both for raw and summed.
DAC_CURRENT = 40_500 # NCO current in micro amps, 40_500 is maximum and 2_250 is minimum.

#Parameters for frequency sweep
FREQ_SWEEP_SPAN = 6e6 #Span of the sweep
CENT_FREQ_ARR = np.flip(np.linspace(CENT_FREQ-FREQ_SWEEP_SPAN/2, CENT_FREQ+FREQ_SWEEP_SPAN/2, 200)) #Array for the central freqs of the sweep
NR_CENT_FREQ = len(CENT_FREQ_ARR)

#Parameters for power sweep
Amplitude, power_array = amplitudeArray(-22,-28,-2,-14)
NR_AMPLITUDE = len(Amplitude)
NR_AVE = 1

Mag = np.zeros((int(NR_AMPLITUDE),int(NR_CENT_FREQ),int(NR_STEPS+1)))
Pha = np.zeros((int(NR_AMPLITUDE),int(NR_CENT_FREQ),int(NR_STEPS+1)))

ff = NR_CENT_FREQ - 1
for f in CENT_FREQ_ARR:
    #print(ff)
    NCO_FREQ = f - DETUNING # Numerically Controlled Oscillator (NCO) frequency. Can be defined separately for input and output. Riccardo says bad idea.

    with lockin.Lockin(ext_ref_clk=False, address=ADDRESS, **CONVERTER_CONFIGURATION) as lck:

        lck.hardware.set_adc_attenuation(INPUT_PORT, 0.0) # Attenuation at input, why would you though?
        lck.hardware.set_dac_current(SG_PORT, DAC_CURRENT) # Set NCO current for output.
        lck.hardware.configure_mixer(NCO_FREQ, in_ports=INPUT_PORT, out_ports=[SG_PORT], 
                                     in_phase = NCO_PHASE_IN, out_phase = NCO_PHASE_OUT, sync=True) # Configure input and output NCOs.

        lck.set_phase_reset(False) # Reset phase of ig and og at the start of every lockin cycle.
        lck.set_dither(DITHER, SG_PORT) # Adds dither to the output ports when set True.

        freq_sg, df = lck.tune(SG_FREQ_OUT,DF) # Tunes the sampling rate in such a way that each lockin cycle has n full wavelengths.

        sgg = lck.add_output_group(ports=SG_PORT, nr_freq=NR_FREQS_SG) # Create output group.
        sgg.set_frequencies(freq_sg) # Set output group detunings.
        sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
        freq_in, df = lck.tune(FREQ_IN,DF) # Previous was output group, this one is input.
        lck.set_df(df) # Set Sampling rate according to the tuning.


        ig = lck.add_input_group(INPUT_PORT, nr_freq=NR_FREQS_IN) # Create input group.
        ig.set_frequencies(freq_in) # Set input group detunings.
        ig.set_phases(phases=PHASE_IN) # Set input group phases. Rotating this equals basis transformation.

        #lck.hardware.set_inv_sinc([SG_PORT],2)

        lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
        lck.hardware.sleep(.2) # Sleep for 0.1 second as outputs are turned on and off during apply.

        jj = 0
        for AMP in Amplitude:
            # Set amplitude of the IF for experiment
            lck.hardware.blank_output(ports=[SG_PORT], state=False) # Reverse blanking outputs for excited state data.
            lck.hardware.sleep(0.1, False) # Sleep for a short duration to make sure device is in steady state.
            sgg.set_amplitudes([AMP,AMP]) # Set output group amplitudes.
            sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
            lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
            lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.

            # pixel_dict = lck.get_pixels(NR_MEAS, fir_coeffs=coeffs) # Measure a number of pixels: Measure IQ data.
            pixel_dict = lck.get_pixels(NR_MEAS) # Measure a number of pixels: Measure IQ data.
            freq, pixel_i, pixel_q = pixel_dict[INPUT_PORT] # Get IQ data.
            IQ1, IQ2 = utils.untwist_downconversion(pixel_i, pixel_q) # Separate lower and higher sidebands.

            for ii in range(NR_FREQS_IN):
                Mag[jj,ff,ii] = np.mean(np.absolute(IQ2[:,ii]))
                Pha[jj,ff,ii] = np.mean(np.angle(IQ2[:,ii], deg=False))
            jj = jj + 1

        ff = ff - 1

        sgg.set_amplitudes(np.zeros(NR_FREQS_SG))
        lck.set_trigger_out(0)
        lck.apply_settings()
        lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.
print('Measurement successful!')
# Out:
# Measurement successful!

# %%
now = datetime.datetime.now()  
folder = r'C:\Users\Demag\PycharmProjects\ColdMeasurements\DeMag\DATA\IMS_summer_pro\Presto data'
file = r'Presto_IMS_onres_[-22 to -28]_' + now.strftime(r'%Y%m%d%H%M%S') + '.mat'
file_name = folder +'\\' + file

# sio.savemat('DataIntermodulationDistortion_' + now.strftime("%Y_%m_%d_%H_%M_%S") + '.mat' , 
sio.savemat(file_name, 
            {'mag': Mag, 'pha': Pha, 'freq': FREQ_IN_MULT, 'sweep_cent_freq': CENT_FREQ, 'span': FREQ_SWEEP_SPAN, 'power': power_array})
print('File download successful!')
# Out:
# File download successful!

# %%
print((-freq_sg[0]+freq_sg[1])/2)
print((freq_in-freq_in[40]))
# Out:
# 100.0
# [-4000. -3900. -3800. -3700. -3600. -3500. -3400. -3300. -3200. -3100.
#  -3000. -2900. -2800. -2700. -2600. -2500. -2400. -2300. -2200. -2100.
#  -2000. -1900. -1800. -1700. -1600. -1500. -1400. -1300. -1200. -1100.
#  -1000.  -900.  -800.  -700.  -600.  -500.  -400.  -300.  -200.  -100.
#      0.   100.   200.   300.   400.   500.   600.   700.   800.   900.
#   1000.  1100.  1200.  1300.  1400.  1500.  1600.  1700.  1800.  1900.
#   2000.  2100.  2200.  2300.  2400.  2500.  2600.  2700.  2800.  2900.
#   3000.  3100.  3200.  3300.  3400.  3500.  3600.  3700.  3800.  3900.
#   4000.]

# %%
amplitudeArray(-14,-14,-5,-14)
# Out:
# array([0.5])

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,15))
ax[0].plot(np.log10(np.absolute(IQ2[:,37])))
ax[1].plot(np.angle(IQ2[:,37]))

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,15))
ax[0].plot(np.log10(Mag[0,2,:]))
ax[1].plot(Pha[0,2,:])

# %%
# ******************************
# *** define some parameters ***
# ******************************

INPUT_PORT = 5 # Somewhat confusingly, input is the listening port,
SG_PORT = 1
file_number = 1

DEL_OMEGA = 200
NR_STEPS = 80
DETUNING = 0.30e9
DF = 10 * 1e0 # Sampling Rate.
CENT_FREQ = 3.798 * 1e9
NCO_PHASE_OUT = 0*np.pi/180 # NCO output phase.
NCO_PHASE_IN = 0*np.pi/180 # NCO input phase.

OMEGA1 = -DEL_OMEGA/2
OMEGA2 = DEL_OMEGA/2

SG_FREQ_OUT = DETUNING + np.array([OMEGA1, OMEGA2])
FREQ_IN_MULT = np.mean(SG_FREQ_OUT)+np.linspace(OMEGA1*(NR_STEPS/2),OMEGA2*(NR_STEPS/2),NR_STEPS+1) # Lets gather data on multiple freequencies at the same time.
FREQ_IN = FREQ_IN_MULT
NR_FREQS_SG = len(SG_FREQ_OUT) # Number of output detunings, needed for method.
NR_FREQS_IN = len(FREQ_IN) # Same for input.
NR_MODES = NR_FREQS_IN/2
PHASE_SG = np.array([0 * np.pi/16, 0 * np.pi/16]) # Output group phase.
PHASE_SG_Q = PHASE_SG - np.pi/2
PHASE_IN = [0 * np.pi/16] # Input group phase.

DITHER = True 

NR_MEAS = 1 * 1e2 # Number of measured points both for raw and summed.
DAC_CURRENT = 40_500 # NCO current in micro amps, 40_500 is maximum and 2_250 is minimum.

#Parameters for frequency sweep
FREQ_SWEEP_SPAN = 8e6 #Span of the sweep
#CENT_FREQ_ARR = np.flip(np.linspace(CENT_FREQ-FREQ_SWEEP_SPAN/2, CENT_FREQ+FREQ_SWEEP_SPAN/2, 100)) #Array for the central freqs of the sweep
CENT_FREQ_ARR = np.array([CENT_FREQ])
NR_CENT_FREQ = len(CENT_FREQ_ARR)


#Parameters for power sweep
Amplitude, power_array = amplitudeArray(-15,-40,-5,-14)
AMP = 0.5
NR_AMPLITUDE = len(Amplitude)
NR_AVE = 1

#Mag = np.zeros((int(NR_AMPLITUDE),int(NR_CENT_FREQ),int(NR_STEPS+1)))
#Pha = np.zeros((int(NR_AMPLITUDE),int(NR_CENT_FREQ),int(NR_STEPS+1)))
Mag = np.zeros(int(NR_STEPS+1))
Pha = np.zeros(int(NR_STEPS+1))

#ff = NR_CENT_FREQ - 1
#for f in CENT_FREQ_ARR:
NCO_FREQ = CENT_FREQ - DETUNING # Numerically Controlled Oscillator (NCO) frequency. Can be defined separately for input and output. Riccardo says bad idea.

with lockin.Lockin(ext_ref_clk=False, address=ADDRESS, **CONVERTER_CONFIGURATION) as lck:

    lck.hardware.set_adc_attenuation(INPUT_PORT, 0.0) # Attenuation at input, why would you though?
    lck.hardware.set_dac_current(SG_PORT, DAC_CURRENT) # Set NCO current for output.
    lck.hardware.configure_mixer(NCO_FREQ, in_ports=INPUT_PORT, out_ports=[SG_PORT], 
                                 in_phase = NCO_PHASE_IN, out_phase = NCO_PHASE_OUT, sync=True) # Configure input and output NCOs.

    lck.set_phase_reset(False) # Reset phase of ig and og at the start of every lockin cycle.
    lck.set_dither(DITHER, SG_PORT) # Adds dither to the output ports when set True.

    freq_sg, df = lck.tune(SG_FREQ_OUT,DF) # Tunes the sampling rate in such a way that each lockin cycle has n full wavelengths.

    sgg = lck.add_output_group(ports=SG_PORT, nr_freq=NR_FREQS_SG) # Create output group.
    sgg.set_frequencies(freq_sg) # Set output group detunings.
    sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
    freq_in, df = lck.tune(FREQ_IN,DF) # Previous was output group, this one is input.
    lck.set_df(df) # Set Sampling rate according to the tuning.


    ig = lck.add_input_group(INPUT_PORT, nr_freq=NR_FREQS_IN) # Create input group.
    ig.set_frequencies(freq_in) # Set input group detunings.
    ig.set_phases(phases=PHASE_IN) # Set input group phases. Rotating this equals basis transformation.

    #lck.hardware.set_inv_sinc([SG_PORT],2)

    lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
    lck.hardware.sleep(.2) # Sleep for 0.1 second as outputs are turned on and off during apply.

    #jj = 0
    #for AMP in Amplitude:
    # Set amplitude of the IF for experiment
    lck.hardware.blank_output(ports=[SG_PORT], state=False) # Reverse blanking outputs for excited state data.
    lck.hardware.sleep(0.1, False) # Sleep for a short duration to make sure device is in steady state.
    sgg.set_amplitudes([AMP,AMP]) # Set output group amplitudes.
    sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
    lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
    lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.

    # pixel_dict = lck.get_pixels(NR_MEAS, fir_coeffs=coeffs) # Measure a number of pixels: Measure IQ data.
    pixel_dict = lck.get_pixels(NR_MEAS) # Measure a number of pixels: Measure IQ data.
    freq, pixel_i, pixel_q = pixel_dict[INPUT_PORT] # Get IQ data.
    IQ1, IQ2 = utils.untwist_downconversion(pixel_i, pixel_q) # Separate lower and higher sidebands.

    for ii in range(NR_FREQS_IN):
        #Mag[jj,ff,ii] = np.mean(np.absolute(IQ[:,ii]))
        #Pha[jj,ff,ii] = np.mean(np.angle(IQ[:,ii], deg=False))
        Mag[ii] = np.mean(np.absolute(IQ2[:,ii]))
        Pha[ii] = np.mean(np.angle(IQ2[:,ii], deg=False))
    #jj = jj + 1

    #ff = ff - 1

    sgg.set_amplitudes(np.zeros(NR_FREQS_SG))
    lck.set_trigger_out(0)
    lck.apply_settings()
    lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,15))
ax[0].plot(np.log10(Mag[:]))
ax[1].plot(Pha[:])

# %%
# ******************************
# *** define some parameters ***
# ******************************

INPUT_PORT = 1 # Somewhat confusingly, input is the listening port,
SG_PORT = 4
file_number = 32

DEL_OMEGA = 2e3
NR_STEPS = 80
DETUNING = 0.30e9
DF = 5 * 1e1 # Sampling Rate.
CENT_FREQ = 3.79885 * 1e9
NCO_FREQ = CENT_FREQ - DETUNING # Numerically Controlled Oscillator (NCO) frequency. Can be defined separately for input and output. Riccardo says bad idea.
NCO_PHASE_OUT = 0*np.pi/180 # NCO output phase.
NCO_PHASE_IN = 0*np.pi/180 # NCO input phase.

#Parameters for frequency sweep
FREQ_SWEEP_SPAN = 6e6 #Span of the sweep
FREQ_SWEEP_ARR = np.linspace(-FREQ_SWEEP_SPAN/2, FREQ_SWEEP_SPAN/2, 1) #Array for the central freqs of the sweep
NR_FREQ_SWEEP_ARR = len(FREQ_SWEEP_ARR)

#Parameters for power sweep
Amplitude = np.linspace(0.1,0.5,20)
Amplitude = [inputConv(-10,50,40.5e-6,18)]
NR_AMPLITUDE = len(Amplitude)
NR_AVE = 1

Mag = np.zeros((int(NR_AMPLITUDE),int(NR_FREQ_SWEEP_ARR),int(NR_STEPS+1)))
Pha = np.zeros((int(NR_AMPLITUDE),int(NR_FREQ_SWEEP_ARR),int(NR_STEPS+1)))


ff = NR_FREQ_SWEEP_ARR - 1
for f in FREQ_SWEEP_ARR:

    OMEGA1 = -DEL_OMEGA/2 + f
    OMEGA2 = DEL_OMEGA/2 + f

    SG_FREQ_OUT = DETUNING + np.array([OMEGA1, OMEGA2])
    FREQ_IN_MULT = np.mean(SG_FREQ_OUT)+np.linspace(OMEGA1*(NR_STEPS/2),OMEGA2*(NR_STEPS/2),NR_STEPS+1) # Lets gather data on multiple freequencies at the same time.
    FREQ_IN = FREQ_IN_MULT
    NR_FREQS_SG = len(SG_FREQ_OUT) # Number of output detunings, needed for method.
    NR_FREQS_IN = len(FREQ_IN) # Same for input.
    NR_MODES = NR_FREQS_IN/2
    PHASE_SG = np.array([0 * np.pi/16, 0 * np.pi/16]) # Output group phase.
    PHASE_SG_Q = PHASE_SG - np.pi/2
    PHASE_IN = [0 * np.pi/16] # Input group phase.

    DITHER = True

    NR_MEAS = 1 * 1e2 # Number of measured points both for raw and summed.
    DAC_CURRENT = 2_250 # NCO current in micro amps, 40_500 is maximum and 2_250 is minimum.

    with lockin.Lockin(ext_ref_clk=False, address=ADDRESS, **CONVERTER_CONFIGURATION) as lck:

        lck.hardware.set_adc_attenuation(INPUT_PORT, 0.0) # Attenuation at input, why would you though?
        lck.hardware.set_dac_current(SG_PORT, DAC_CURRENT) # Set NCO current for output.
        lck.hardware.configure_mixer(NCO_FREQ, in_ports=INPUT_PORT, out_ports=[SG_PORT], 
                                     in_phase = NCO_PHASE_IN, out_phase = NCO_PHASE_OUT, sync=True) # Configure input and output NCOs.

        lck.set_phase_reset(False) # Reset phase of ig and og at the start of every lockin cycle.
        lck.set_dither(DITHER, SG_PORT) # Adds dither to the output ports when set True.

        freq_sg, df = lck.tune(SG_FREQ_OUT,DF) # Tunes the sampling rate in such a way that each lockin cycle has n full wavelengths.
        freq_in, df = lck.tune(FREQ_IN,DF) # Previous was output group, this one is input.
        lck.set_df(df) # Set Sampling rate according to the tuning.

        sgg = lck.add_output_group(ports=SG_PORT, nr_freq=NR_FREQS_SG) # Create output group.
        sgg.set_frequencies(freq_sg) # Set output group detunings.
        sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.

        ig = lck.add_input_group(INPUT_PORT, nr_freq=NR_FREQS_IN) # Create input group.
        ig.set_frequencies(freq_in) # Set input group detunings.
        ig.set_phases(phases=PHASE_IN) # Set input group phases. Rotating this equals basis transformation.

        #lck.hardware.set_inv_sinc([SG_PORT],2)

        lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
        lck.hardware.sleep(.2) # Sleep for 0.1 second as outputs are turned on and off during apply.

        for jj, AMP in enumerate(Amplitude):
            #  Set amplitude of the IF for experiment
            lck.hardware.blank_output(ports=[SG_PORT], state=False) # Reverse blanking outputs for excited state data.
            lck.hardware.sleep(0.1, False) # Sleep for a short duration to make sure device is in steady state.
            sgg.set_amplitudes([AMP,AMP]) # Set output group amplitudes.
            sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
            lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
            lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.

            # pixel_dict = lck.get_pixels(NR_MEAS, fir_coeffs=coeffs) # Measure a number of pixels: Measure IQ data.
            pixel_dict = lck.get_pixels(NR_MEAS) # Measure a number of pixels: Measure IQ data.
            freq, pixel_i, pixel_q = pixel_dict[INPUT_PORT] # Get IQ data.
            _, IQ = utils.untwist_downconversion(pixel_i, pixel_q) # Separate lower and higher sidebands.

            for ii in range(NR_FREQS_IN):
                IQ[:,ii] = (IQ[:,ii]-np.mean(IQ[:,ii]))
                Mag[jj,ff,ii] = np.mean(np.absolute(IQ[:,ii]))
                Pha[jj,ff,ii] = np.mean(np.angle(IQ[:,ii], deg=False))

        ff = ff - 1


        sgg.set_amplitudes(np.zeros(NR_FREQS_SG))
        lck.set_trigger_out(0)
        lck.apply_settings()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,15))
ax[0].plot(np.log10(Mag[0,4,:]))

# %%
sgg.set_amplitudes(0.0)

# %%
sgg.set_amplitudes(0)
lck.apply_settings()

# %%
DAC_CURRENT = 2_500 # NCO current in micro amps, 40_500 is maximum and 2_250 is minimum.
CENT_FREQ = 3.79885 * 1e9
NCO_FREQ = CENT_FREQ - DETUNING
DITHER = True
DF = 5 * 1e1 # Sampling Rate.
PHASE_SG = 0 * np.pi/16 # Output group phase.
PHASE_SG_Q = PHASE_SG - np.pi/2
PHASE_IN = [0 * np.pi/16] # Input group phase.
AMPLITUDE = np.linspace(0.0,1,10)
NR_AMP = len(AMPLITUDE)
power = np.zeros(NR_AMP)

DEL_OMEGA = 200
OMEGA1 = DEL_OMEGA/2
OMEGA2 = DEL_OMEGA/2
SG_FREQ_OUT = DETUNING + np.array([OMEGA1, OMEGA2])

i = 0
for AMP in AMPLITUDE:
    with lockin.Lockin(ext_ref_clk=False, address=ADDRESS, **CONVERTER_CONFIGURATION) as lck:

        lck.hardware.set_adc_attenuation(INPUT_PORT, 0.0) # Attenuation at input, why would you though?
        lck.hardware.set_dac_current(SG_PORT, DAC_CURRENT) # Set NCO current for output.
        lck.hardware.configure_mixer(NCO_FREQ, in_ports=INPUT_PORT, out_ports=[SG_PORT], 
                                     in_phase = NCO_PHASE_IN, out_phase = NCO_PHASE_OUT, sync=True) # Configure input and output NCOs.

        lck.set_phase_reset(False) # Reset phase of ig and og at the start of every lockin cycle.
        lck.set_dither(DITHER, SG_PORT) # Adds dither to the output ports when set True.

        freq_sg, df = lck.tune(SG_FREQ_OUT,DF) # Tunes the sampling rate in such a way that each lockin cycle has n full wavelengths.
        freq_in, df = lck.tune(SG_FREQ_OUT,DF) # Previous was output group, this one is input.
        lck.set_df(df) # Set Sampling rate according to the tuning.

        sgg = lck.add_output_group(ports=SG_PORT, nr_freq=1) # Create output group.
        sgg.set_frequencies(freq_sg) # Set output group detunings.
        sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.

        ig = lck.add_input_group(INPUT_PORT, nr_freq=1) # Create input group.
        ig.set_frequencies(freq_in) # Set input group detunings.
        ig.set_phases(phases=PHASE_IN) # Set input group phases. Rotating this equals basis transformation.

        lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
        lck.hardware.sleep(.2) # Sleep for 0.1 second as outputs are turned on and off during apply.

        #  Set amplitude of the IF for experiment
        lck.hardware.blank_output(ports=[SG_PORT], state=False) # Reverse blanking outputs for excited state data.
        sgg.set_amplitudes(AMP) # Set output group amplitudes.
        sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
        lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
        lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.
        
    power(i) = anri.get_data()
    i = i + 1
# Out:
#   Cell In[50], line 52
#     power(i) = anri.get_data()
#     ^
# SyntaxError: cannot assign to function call

# %%
with lockin.Lockin(ext_ref_clk=False, address=ADDRESS, **CONVERTER_CONFIGURATION) as lck:
    sgg.set_amplitudes([0,0])
    lck.set_trigger_out(0)
    lck.apply_settings()

# %%
INPUT_PORT = 1 # Somewhat confusingly, input is the listening port,
SG_PORT = 1
DEL_OMEGA = 200
NR_STEPS = 80
DF = 5 * 1e1 # Sampling Rate.
CENT_FREQ = 3.798 * 1e9
NCO_FREQ = CENT_FREQ - DETUNING # Numerically Controlled Oscillator (NCO) frequency. Can be defined separately for input and output. Riccardo says bad idea.
NCO_PHASE_OUT = 0*np.pi/180 # NCO output phase.
NCO_PHASE_IN = 0*np.pi/180 # NCO input phase.
DAC_CURRENT = 40_500 # NCO current in micro amps, 40_500 is maximum and 2_250 is minimum.
DETUNING = 0.3e9
NCO_FREQ = CENT_FREQ - DETUNING
DITHER = True
DF = 5 * 1e1 # Sampling Rate.
PHASE_SG = np.array([0 * np.pi/16, 8 * np.pi/16]) # Output group phase.
PHASE_SG_Q = PHASE_SG - np.pi/2
PHASE_IN = [0 * np.pi/16] # Input group phase.
AMPLITUDE = np.linspace(0.0,1,10)
NR_AMP = len(AMPLITUDE)
power = np.zeros(NR_AMP)

DEL_OMEGA = 200
OMEGA1 = DEL_OMEGA/2 
OMEGA2 = -DEL_OMEGA/2 
SG_FREQ_OUT = DETUNING + np.array([OMEGA1, OMEGA2])


with lockin.Lockin(ext_ref_clk=False, address=ADDRESS, **CONVERTER_CONFIGURATION) as lck:

    lck.hardware.set_adc_attenuation(INPUT_PORT, 0.0) # Attenuation at input, why would you though?
    lck.hardware.set_dac_current(SG_PORT, DAC_CURRENT) # Set NCO current for output.
    lck.hardware.configure_mixer(NCO_FREQ, out_ports=[SG_PORT], out_phase = NCO_PHASE_OUT, sync=False) # Configure input and output NCOs.
    lck.hardware.configure_mixer(NCO_FREQ+CENT_FREQ, in_ports=INPUT_PORT,  in_phase = NCO_PHASE_IN, sync=True) # Configure input and

    lck.set_phase_reset(False) # Reset phase of ig and og at the start of every lockin cycle.
    lck.set_dither(DITHER, SG_PORT) # Adds dither to the output ports when set True.

    freq_sg, df = lck.tune(SG_FREQ_OUT,DF) # Tunes the sampling rate in such a way that each lockin cycle has n full wavelengths.
    freq_in, df = lck.tune(SG_FREQ_OUT,DF) # Previous was output group, this one is input.
    lck.set_df(df) # Set Sampling rate according to the tuning.

    sgg = lck.add_output_group(ports=SG_PORT, nr_freq=2) # Create output group.
    sgg.set_frequencies(freq_sg) # Set output group detunings.
    sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.

    ig = lck.add_input_group(INPUT_PORT, nr_freq=2) # Create input group.
    ig.set_frequencies(freq_in) # Set input group detunings.
    ig.set_phases(phases=PHASE_IN) # Set input group phases. Rotating this equals basis transformation.

    lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
    lck.hardware.sleep(.2) # Sleep for 0.1 second as outputs are turned on and off during apply.

    #  Set amplitude of the IF for experiment
    lck.hardware.blank_output(ports=[SG_PORT], state=False) # Reverse blanking outputs for excited state data.
    sgg.set_amplitudes([0.5,0.5]) # Set output group amplitudes.
    sgg.set_phases(phases=PHASE_SG, phases_q=PHASE_SG_Q) # Set output group phases.
    lck.apply_settings() # For the previously given changes to take effect, the settings need to be applied.
    lck.hardware.sleep(0.1) # Sleep for 0.1 second as outputs are turned on and off during apply.

# %%
def inputConv(DBM, ZERO_LEVEL): #[Amplification] = dB
    AMP = 0.5*np.power(10,(abs(ZERO_LEVEL)+DBM)/20)
    return AMP

# %%
def amplitudeArray(start_pow, end_pow, pow_inc, zero_level):
    amp_span = int((abs(end_pow) - abs(start_pow)) / abs(pow_inc))
    amp_arr = np.zeros(amp_span+1)
    p_arr = np.zeros(amp_span+1)
    p = start_pow
    i = 0
    while p >= end_pow:
        amp_arr[i] = inputConv(p, zero_level)
        p_arr[i] = p
        i = i + 1
        p = p + pow_inc
    return amp_arr, p_arr

# %%
amplitudeArray(-15, -40, -5, -14)
# Out:
# (array([0.44562547, 0.25059362, 0.14091915, 0.07924466, 0.04456255,
#         0.02505936]),
#  array([-15., -20., -25., -30., -35., -40.]))

# %%
inputConv(-25,-14)
# Out:
# 0.14091914656322269

# %%
anri.set_cent_freq(3.79885 * 1e9)

# %%
vna.
